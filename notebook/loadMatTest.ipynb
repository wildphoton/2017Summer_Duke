# %%
import scipy.io
import numpy as np

filepath = '/home/helios/Documents/data/Model_zoo/imagenet-vgg-verydeep-19.mat'
model_data = scipy.io.loadmat(filepath)

# %%
print(model_data['normalization'][0][0][1])
# Out:
# 1.0

# %%
mean_pixel = np.mean(mean, axis=(0, 1))

# %%
layers = np.squeeze(model_data['layers'])
#layers = (model_data['layers'])

# %%
layer1 = layers[0]
#kernels, bias = weights[1][0][0][0][0]
layer1_weights = layer1[0][0][0]
w,b = layer1_weights[0]

# %%
#print((layer1[0][0]))
print(w.shape)
# Out:
# (3, 3, 3, 64)

# %%
classes = model_data['classes']
#print(classes)

# %%
name = classes['name']
print((name))
# Out:
# [[ array([[array(['n01440764'],
#       dtype='<U9'),
#         array(['n01443537'],
#       dtype='<U9'),
#         array(['n01484850'],
#       dtype='<U9'),
#         array(['n01491361'],
#       dtype='<U9'),
#         array(['n01494475'],
#       dtype='<U9'),
#         array(['n01496331'],
#       dtype='<U9'),
#         array(['n01498041'],
#       dtype='<U9'),
#         array(['n01514668'],
#       dtype='<U9'),
#         array(['n01514859'],
#       dtype='<U9'),
#         array(['n01518878'],
#       dtype='<U9'),
#         array(['n01530575'],
#       dtype='<U9'),
#         array(['n01531178'],
#       dtype='<U9'),
#         array(['n01532829'],
#       dtype='<U9'),
#         array(['n01534433'],
#       dtype='<U9'),
#         array(['n01537544'],
#       dtype='<U9'),
#         array(['n01558993'],
#       dtype='<U9'),
#         array(['n01560419'],
#       dtype='<U9'),
#         array(['n01580077'],
#       dtype='<U9'),
#         array(['n01582220'],
# ...

# %%
filepath = '/home/helios/Documents/zhenlinx/code/2017Summer/test/struct.mat'
test_data = scipy.io.loadmat(filepath, squeeze_me=True) 
S = test_data['S']
C = test_data['C']
print(test_data)
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: GLNXA64, Created on: Fri Jun  9 10:54:06 2017', '__version__': '1.0', '__globals__': [], 'C': array(['a', 'b', 'c'], dtype=object), 'S': array((['a', 'b', 'c'], [[0.8147236863931789, 0.9133758561390194, 0.2784982188670484], [0.9057919370756192, 0.6323592462254095, 0.5468815192049838], [0.12698681629350606, 0.09754040499940952, 0.9575068354342976]], 1, [0.9648885351992765, 0.15761308167754828, 0.9705927817606157], 'test'),
#       dtype=[('name', 'O'), ('array', 'O'), ('num', 'O'), ('vector', 'O'), ('char', 'O')])}
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-237-9c3ee6b4d395> in <module>()
#       4 C = test_data['C']
#       5 print(test_data)
# ----> 6 print(type(test_data.dtype))
#
# AttributeError: 'dict' object has no attribute 'dtype'

# %%
name = S['name']
np.atleast_1d(name)
# Out:
# <class 'numpy.dtype'>

# %%
Ss= np.squeeze(S)
S00 = S[0][0]
print(type(S))
print(S)
print('\n')

print(type(Ss))
print(Ss)
print('\n')

print(type(S00))
print(S00)
print('\n')
# Out:
# <class 'numpy.ndarray'>
# [[ ([[array(['a'],
#       dtype='<U1'), array(['b'],
#       dtype='<U1'), array(['c'],
#       dtype='<U1')]], [[0.8147236863931789, 0.9133758561390194, 0.2784982188670484], [0.9057919370756192, 0.6323592462254095, 0.5468815192049838], [0.12698681629350606, 0.09754040499940952, 0.9575068354342976]], [[1]], [[0.9648885351992765, 0.15761308167754828, 0.9705927817606157]], ['test'])]]
#
#
# <class 'numpy.ndarray'>
# ([[array(['a'],
#       dtype='<U1'), array(['b'],
#       dtype='<U1'), array(['c'],
#       dtype='<U1')]], [[0.8147236863931789, 0.9133758561390194, 0.2784982188670484], [0.9057919370756192, 0.6323592462254095, 0.5468815192049838], [0.12698681629350606, 0.09754040499940952, 0.9575068354342976]], [[1]], [[0.9648885351992765, 0.15761308167754828, 0.9705927817606157]], ['test'])
#
#
# <class 'numpy.void'>
# ([[array(['a'],
#       dtype='<U1'), array(['b'],
#       dtype='<U1'), array(['c'],
# ...

# %%
name = np.squeeze(Ss['name'])
print((S.shape))
# Out:
# (1, 1)

# %%
print(C)
print(type(C))
# Out:
# [[array(['a'],
#       dtype='<U1') array(['b'],
#       dtype='<U1')
#   array(['c'],
#       dtype='<U1')]]
# <class 'numpy.ndarray'>

# %%
Cs = np.squeeze(C)
print(type(Cs))
# Out:
# <class 'numpy.ndarray'>

# %%
print(C)
print(Cs[0][0])
# Out:
# [[array(['a'],
#       dtype='<U1') array(['b'],
#       dtype='<U1')
#   array(['c'],
#       dtype='<U1')]]
# a
